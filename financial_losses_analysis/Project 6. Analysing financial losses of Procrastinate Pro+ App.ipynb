# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Первичный-этап---выгрузка-данных,-проверка-и-вводные-правки" data-toc-modified-id="Первичный-этап---выгрузка-данных,-проверка-и-вводные-правки-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Первичный этап - выгрузка данных, проверка и вводные правки</a></span><ul class="toc-item"><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Загрузка-необходимых-библиотек-и-настройка-инструментария" data-toc-modified-id="Загрузка-необходимых-библиотек-и-настройка-инструментария-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Загрузка необходимых библиотек и настройка инструментария</a></span></li><li><span><a href="#Выгрузка-данных-и-первичный-&quot;exploratory-анализ&quot;" data-toc-modified-id="Выгрузка-данных-и-первичный-&quot;exploratory-анализ&quot;-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Выгрузка данных и первичный "exploratory-анализ"</a></span></li><li><span><a href="#Задайте-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии." data-toc-modified-id="Задайте-функции-для-расчёта-и-анализа-LTV,-ROI,-удержания-и-конверсии.-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Составьте-профили-пользователей.-Определите-минимальную-и-максимальную-даты-привлечения-пользователей." data-toc-modified-id="Составьте-профили-пользователей.-Определите-минимальную-и-максимальную-даты-привлечения-пользователей.-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.</a></span></li><li><span><a href="#Выясните,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны." data-toc-modified-id="Выясните,-из-каких-стран-пользователи-приходят-в-приложение-и-на-какую-страну-приходится-больше-всего-платящих-пользователей.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-из-каждой-страны.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.</a></span></li><li><span><a href="#Узнайте,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства." data-toc-modified-id="Узнайте,-какими-устройствами-пользуются-клиенты-и-какие-устройства-предпочитают-платящие-пользователи.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-устройства.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.</a></span></li><li><span><a href="#Изучите-рекламные-источники-привлечения-и-определите-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения." data-toc-modified-id="Изучите-рекламные-источники-привлечения-и-определите-каналы,-из-которых-пришло-больше-всего-платящих-пользователей.-Постройте-таблицу,-отражающую-количество-пользователей-и-долю-платящих-для-каждого-канала-привлечения.-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.</a></span></li><li><span><a href="#Маркетинг" data-toc-modified-id="Маркетинг-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Маркетинг</a></span></li><li><span><a href="#Оцените-окупаемость-рекламы" data-toc-modified-id="Оцените-окупаемость-рекламы-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Оцените окупаемость рекламы</a></span></li></ul></li><li><span><a href="#Общие-выводы" data-toc-modified-id="Общие-выводы-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Общие выводы</a></span></li></ul></div>

# %% [markdown]
# ## Первичный этап - выгрузка данных, проверка и вводные правки

# %% [markdown]
# ### Описание проекта

# %% [markdown]
# **Ключевая проблема:** "Вы — маркетинговый аналитик развлекательного приложения Procrastinate Pro+. Несмотря на огромные вложения в рекламу, последние несколько месяцев компания терпит убытки. Ваша задача — разобраться в причинах и помочь компании выйти в плюс"
#
# **Задачи проекта:**
# - Выяснить откуда приходят пользователи и какими устройствами они пользуются,
# - Установить сколько стоит привлечение пользователей из различных рекламных каналов;
# - Рассчитать сколько денег приносит каждый клиент,
# - Рассчитать когда расходы на привлечение клиента окупаются,
# - Установить какие факторы мешают привлечению клиентов.
#
# **Данные**: Работа осуществлялась на основании данных о пользователях, привлечённых с 1 мая по 27 октября 2019 года.
# - Файл `visits_info_short.csv` хранит лог сервера с информацией о посещениях сайта
#     - *User Id* — уникальный идентификатор пользователя,
#     - *Region* — страна пользователя,
#     - *Device* — тип устройства пользователя,
#     - *Channel* — идентификатор источника перехода,
#     - *Session Start* — дата и время начала сессии,
#     - *Session End* — дата и время окончания сессии.
# - Файл `orders_info_short.csv`хранит информацию о заказах
#     - *User Id* — уникальный идентификатор пользователя,
#     - *Event Dt* — дата и время покупки,
#     - *Revenue* — сумма заказа.
# - Файл `costs_info_short.csv`хранит информацию о расходах на рекламу.
#     - *dt* — дата проведения рекламной кампании,
#     - *Channel* — идентификатор рекламного источника,
#     - *costs* — расходы на эту кампанию.
#
# **Структура**: Работа в данном проекте осуществлялась в соответствии с конкретными, предоставленными авторами проекта задачами. Проект структурирован по основным тематическим блокам.

# %% [markdown]
# ### Загрузка необходимых библиотек и настройка инструментария

# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

#Добавляем полоску загрузки для визуализации работ с итерацией
from tqdm import tqdm_notebook
tqdm_notebook().pandas()

#Настройки pandas
pd.set_option('display.max_columns', 40) #Отображаем все колонки
pd.set_option('display.float_format', lambda x: '%.2f' % x) # Отображаем большие числа без точки

print("Загрузка завершена")
# Out:
# /tmp/ipykernel_104/3989791627.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   tqdm_notebook().pandas()
# 0it [00:00, ?it/s]
# Загрузка завершена

# %% [markdown]
# ### Выгрузка данных и первичный "exploratory-анализ"

# %% [markdown]
# Загрузите данные о визитах, заказах и рекламных расходах из CSV-файлов в переменные.
#
# **Пути к файлам**
#
# - визиты: `/datasets/visits_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/visits_info_short.csv);
# - заказы: `/datasets/orders_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/orders_info_short.csv);
# - расходы: `/datasets/costs_info_short.csv`. [Скачать датасет](https://code.s3.yandex.net/datasets/costs_info_short.csv).
#
# Изучите данные и выполните предобработку. Есть ли в данных пропуски и дубликаты? Убедитесь, что типы данных во всех колонках соответствуют сохранённым в них значениям. Обратите внимание на столбцы с датой и временем.

# %%
#Загружаем данные в переменные

visits = pd.read_csv('/datasets/visits_info_short.csv')
orders = pd.read_csv('/datasets/orders_info_short.csv')
costs = pd.read_csv('/datasets/costs_info_short.csv')

#Общие данные о датафреймах
dfs = [visits, orders, costs]
names = ['visits', 'orders', 'costs']
for i, df in enumerate(dfs):
    print(f'Размер датафрейма {names[i]} составляет {df.shape[0]} строк и {df.shape[1]} столбцов')
    display(df.head(2))
    print()
# Out:
# Размер датафрейма visits составляет 309901 строк и 6 столбцов
#         User Id         Region  Device  Channel        Session Start  \
# 0  981449118918  United States  iPhone  organic  2019-05-01 02:36:01
# 1  278965908054  United States  iPhone  organic  2019-05-01 04:46:31
#
#            Session End
# 0  2019-05-01 02:45:01
# 1  2019-05-01 04:47:35
# Размер датафрейма orders составляет 40212 строк и 3 столбцов
#         User Id             Event Dt  Revenue
# 0  188246423999  2019-05-01 23:09:52     4.99
# 1  174361394180  2019-05-01 12:24:04     4.99
# Размер датафрейма costs составляет 1800 строк и 3 столбцов
#            dt   Channel  costs
# 0  2019-05-01  FaceBoom 113.30
# 1  2019-05-02  FaceBoom  78.10

# %% [markdown]
# Давайте обратим внимание на **типы столбцов:**

# %%
for i, df in enumerate(dfs):
    print(f'Анализируем данные из таблицы {names[i]}')
    df.info()
    print()
    print()
# Out:
# Анализируем данные из таблицы visits
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   User Id        309901 non-null  int64
#  1   Region         309901 non-null  object
#  2   Device         309901 non-null  object
#  3   Channel        309901 non-null  object
#  4   Session Start  309901 non-null  object
#  5   Session End    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#
#
# Анализируем данные из таблицы orders
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   User Id   40212 non-null  int64
#  1   Event Dt  40212 non-null  object
#  2   Revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# ...

# %% [markdown]
# - **Первая проблема** - столбцы лучше привести к нижнему регистру, для простоты написания и анализа.
# - **Вторая проблема** - в столбцах с двумя словами лучше использовать нижнее подчёркивание вместо пробелов.
# - **Третья проблема - тип даных.** Столбцы с временными данными необходимо привести к соответствующим типам для того, чтобы с ними можно было работать.

# %%
for df in dfs:
    df.rename(str.lower, axis='columns', inplace=True)
    df.info()
    print()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session start  309901 non-null  object
#  5   session end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user id   40212 non-null  int64
#  1   event dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# Столбцы **приведены к нижнему регистру.** Перейдём ко второй проблеме:

# %%
line_conversion = {'session start': 'session_start',
                  'session end': 'session_end',
                  'user id': 'user_id',
                  'event dt': 'event_dt'}
for df in dfs:
    df.rename(columns=line_conversion, inplace=True)
    df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309901 entries, 0 to 309900
# Data columns (total 6 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   user_id        309901 non-null  int64
#  1   region         309901 non-null  object
#  2   device         309901 non-null  object
#  3   channel        309901 non-null  object
#  4   session_start  309901 non-null  object
#  5   session_end    309901 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 14.2+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40212 entries, 0 to 40211
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   user_id   40212 non-null  int64
#  1   event_dt  40212 non-null  object
#  2   revenue   40212 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 942.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# ...

# %% [markdown]
# **В названия столбцов добавлены нижние подчёркивания.** Перейдём к третьей проблеме - с типами:

# %%
visits['session_start'] = pd.to_datetime(visits['session_start'])
visits['session_end'] = pd.to_datetime(visits['session_end'])

orders['event_dt'] = pd.to_datetime(orders['event_dt'])

costs['dt'] = pd.to_datetime(costs['dt']).dt.date

# %% [markdown]
# Проблема с типами решена. Давайте посмотрим, **есть ли в данных дубликаты:**

# %%
visits_dubs = visits.duplicated().sum()
orders_dubs = visits.duplicated().sum()
costs_dubs = visits.duplicated().sum()

print(f'Число дубликатов в датафрейме visits = {visits_dubs}')
print(f'Число дубликатов в датафрейме orders = {orders_dubs}')
print(f'Число дубликатов в датафрейме costs = {costs_dubs}')
# Out:
# Число дубликатов в датафрейме visits = 0
# Число дубликатов в датафрейме orders = 0
# Число дубликатов в датафрейме costs = 0

# %% [markdown]
# Дубликатов в данных нет - хорошие новости. А как обстоят дела с **пропусками?**

# %%
print('Посмотрим на датафрейм VISITS')
display(visits.isna().sum())
print('Посмотрим на датафрейм ORDERS')
display(orders.isna().sum())
print('Посмотрим на датафрейм COSTS')
display(costs.isna().sum())
# Out:
# Посмотрим на датафрейм VISITS
# user_id          0
# region           0
# device           0
# channel          0
# session_start    0
# session_end      0
# dtype: int64
# Посмотрим на датафрейм ORDERS
# user_id     0
# event_dt    0
# revenue     0
# dtype: int64
# Посмотрим на датафрейм COSTS
# dt         0
# channel    0
# costs      0
# dtype: int64

# %% [markdown]
# По результатам **первичного этапа:**
#
# - Данные были выгружены из **предложенных таблиц** (`visits_info_short`, `orders_info_short`, `costs_info_short`), проблем с выгрузкой не было.
# - Данные были сохранены в **таблицы (переменные)** `visits`, `orders` и `costs` соответственно.
# - На **этапе предобработки** были произведены следующие операции:
#     - Столбцы в таблицах были приведены к **нижнему регистру, пробелы были заменены на подчёркивания** (`User ID => user_id`)
#     - Был **исправлен тип данных в столбцах, которые обозначают время** (`session_start` и `session_end` в `visits` и `event_dt` в `orders`. `dt` в `costs` был также приведён к формату даты для дальнейшего анализа.
#     - Дубликатов и пропусков в таблицах не обнаружено.
#
#
# На этом **обработка данных завершена - можно приступать к анализу.**

# %% [markdown]
# ### Задайте функции для расчёта и анализа LTV, ROI, удержания и конверсии.
#
# Разрешается использовать функции, с которыми вы познакомились в теоретических уроках.
#
# Это функции для вычисления значений метрик:
#
# - `get_profiles()` — для создания профилей пользователей,
# - `get_retention()` — для подсчёта Retention Rate,
# - `get_conversion()` — для подсчёта конверсии,
# - `get_ltv()` — для подсчёта LTV.
#
# А также функции для построения графиков:
#
# - `filter_data()` — для сглаживания данных,
# - `plot_retention()` — для построения графика Retention Rate,
# - `plot_conversion()` — для построения графика конверсии,
# - `plot_ltv_roi` — для визуализации LTV и ROI.
#
# Давайте **импортируем эти функции:**

# %% [markdown]
# Для начала возьмём **функции для рассчёта:**

# %%
# Функция для создания пользовательских профилей

def get_profiles(visits, orders, costs):

    # находим параметры первых посещений
    profiles = (
        visits.sort_values(by=['user_id', 'session_start'])
        .groupby('user_id')
        .agg(
            {
                'session_start': 'first',
                'channel': 'first',
                'device': 'first',
                'region': 'first',
            }
        )
        .rename(columns={'session_start': 'first_ts'})
        .reset_index()
    )

    # для когортного анализа определяем дату первого посещения
    # и первый день месяца, в который это посещение произошло
    profiles['dt'] = profiles['first_ts'].dt.date
    profiles['month'] = profiles['first_ts'].astype('datetime64[M]')

    # добавляем признак платящих пользователей
    profiles['payer'] = profiles['user_id'].isin(orders['user_id'].unique())

    # считаем количество уникальных пользователей
    # с одинаковыми источником и датой привлечения
    new_users = (
        profiles.groupby(['dt', 'channel'])
        .agg({'user_id': 'nunique'})
        .rename(columns={'user_id': 'unique_users'})
        .reset_index()
    )

    # объединяем траты на рекламу и число привлечённых пользователей
    costs = costs.merge(new_users, on=['dt', 'channel'], how='left')

    # делим рекламные расходы на число привлечённых пользователей
    costs['acquisition_cost'] = costs['costs'] / costs['unique_users']

    # добавляем стоимость привлечения в профили
    profiles = profiles.merge(
        costs[['dt', 'channel', 'acquisition_cost']],
        on=['dt', 'channel'],
        how='left',
    )

    # стоимость привлечения органических пользователей равна нулю
    profiles['acquisition_cost'] = profiles['acquisition_cost'].fillna(0)

    return profiles

# %%
# функция для расчёта удержания

def get_retention(
    profiles,
    visits,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # добавляем столбец payer в передаваемый dimensions список
    dimensions = ['payer'] + dimensions

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - dt.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # собираем «сырые» данные для расчёта удержания
    result_raw = result_raw.merge(
        visits[['user_id', 'session_start']], on='user_id', how='left'
    )
    result_raw['lifetime'] = (
        result_raw['session_start'] - result_raw['first_ts']
    ).dt.days

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу удержания
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # получаем таблицу динамики удержания
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта конверсии

def get_conversion(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - dt.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')

    # определяем дату и время первой покупки для каждого пользователя
    first_purchases = (
        orders.sort_values(by=['user_id', 'event_dt'])
        .groupby('user_id')
        .agg({'event_dt': 'first'})
        .reset_index()
    )

    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        first_purchases[['user_id', 'event_dt']], on='user_id', how='left'
    )

    # рассчитываем лайфтайм для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days

    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users' 
        dimensions = dimensions + ['cohort']

    # функция для группировки таблицы по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        result = df.pivot_table(
            index=dims, columns='lifetime', values='user_id', aggfunc='nunique'
        )
        result = result.fillna(0).cumsum(axis = 1)
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # делим каждую «ячейку» в строке на размер когорты
        # и получаем conversion rate
        result = result.div(result['cohort_size'], axis=0)
        result = result[['cohort_size'] + list(range(horizon_days))]
        result['cohort_size'] = cohort_sizes
        return result

    # получаем таблицу конверсии
    result_grouped = group_by_dimensions(result_raw, dimensions, horizon_days)

    # для таблицы динамики конверсии убираем 'cohort' из dimensions
    if 'cohort' in dimensions: 
        dimensions = []

    # получаем таблицу динамики конверсии
    result_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    # возвращаем обе таблицы и сырые данные
    return result_raw, result_grouped, result_in_time

# %%
# функция для расчёта LTV и ROI

def get_ltv(
    profiles,
    orders,
    observation_date,
    horizon_days,
    dimensions=[],
    ignore_horizon=False,
):

    # исключаем пользователей, не «доживших» до горизонта анализа
    last_suitable_acquisition_date = observation_date
    if not ignore_horizon:
        last_suitable_acquisition_date = observation_date - dt.timedelta(
            days=horizon_days - 1
        )
    result_raw = profiles.query('dt <= @last_suitable_acquisition_date')
    # добавляем данные о покупках в профили
    result_raw = result_raw.merge(
        orders[['user_id', 'event_dt', 'revenue']], on='user_id', how='left'
    )
    # рассчитываем лайфтайм пользователя для каждой покупки
    result_raw['lifetime'] = (
        result_raw['event_dt'] - result_raw['first_ts']
    ).dt.days
    # группируем по cohort, если в dimensions ничего нет
    if len(dimensions) == 0:
        result_raw['cohort'] = 'All users'
        dimensions = dimensions + ['cohort']

    # функция группировки по желаемым признакам
    def group_by_dimensions(df, dims, horizon_days):
        # строим «треугольную» таблицу выручки
        result = df.pivot_table(
            index=dims, columns='lifetime', values='revenue', aggfunc='sum'
        )
        # находим сумму выручки с накоплением
        result = result.fillna(0).cumsum(axis=1)
        # вычисляем размеры когорт
        cohort_sizes = (
            df.groupby(dims)
            .agg({'user_id': 'nunique'})
            .rename(columns={'user_id': 'cohort_size'})
        )
        # объединяем размеры когорт и таблицу выручки
        result = cohort_sizes.merge(result, on=dims, how='left').fillna(0)
        # считаем LTV: делим каждую «ячейку» в строке на размер когорты
        result = result.div(result['cohort_size'], axis=0)
        # исключаем все лайфтаймы, превышающие горизонт анализа
        result = result[['cohort_size'] + list(range(horizon_days))]
        # восстанавливаем размеры когорт
        result['cohort_size'] = cohort_sizes

        # собираем датафрейм с данными пользователей и значениями CAC, 
        # добавляя параметры из dimensions
        cac = df[['user_id', 'acquisition_cost'] + dims].drop_duplicates()

        # считаем средний CAC по параметрам из dimensions
        cac = (
            cac.groupby(dims)
            .agg({'acquisition_cost': 'mean'})
            .rename(columns={'acquisition_cost': 'cac'})
        )

        # считаем ROI: делим LTV на CAC
        roi = result.div(cac['cac'], axis=0)

        # удаляем строки с бесконечным ROI
        roi = roi[~roi['cohort_size'].isin([np.inf])]

        # восстанавливаем размеры когорт в таблице ROI
        roi['cohort_size'] = cohort_sizes

        # добавляем CAC в таблицу ROI
        roi['cac'] = cac['cac']

        # в финальной таблице оставляем размеры когорт, CAC
        # и ROI в лайфтаймы, не превышающие горизонт анализа
        roi = roi[['cohort_size', 'cac'] + list(range(horizon_days))]

        # возвращаем таблицы LTV и ROI
        return result, roi

    # получаем таблицы LTV и ROI
    result_grouped, roi_grouped = group_by_dimensions(
        result_raw, dimensions, horizon_days
    )

    # для таблиц динамики убираем 'cohort' из dimensions
    if 'cohort' in dimensions:
        dimensions = []

    # получаем таблицы динамики LTV и ROI
    result_in_time, roi_in_time = group_by_dimensions(
        result_raw, dimensions + ['dt'], horizon_days
    )

    return (
        result_raw,  # сырые данные
        result_grouped,  # таблица LTV
        result_in_time,  # таблица динамики LTV
        roi_grouped,  # таблица ROI
        roi_in_time,  # таблица динамики ROI
    )

# %% [markdown]
# Далее возьмём и адаптируем **функции для визуализации:**

# %%
# функция для сглаживания фрейма

def filter_data(df, window):
    # для каждого столбца применяем скользящее среднее
    for column in df.columns.values:
        df[column] = df[column].rolling(window).mean() 
    return df

# %%
# функция для визуализации удержания

def plot_retention(retention, retention_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 10))

    # исключаем размеры когорт и удержание первого дня
    retention = retention.drop(columns=['cohort_size', 0])
    # в таблице динамики оставляем только нужный лайфтайм
    retention_history = retention_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # если в индексах таблицы удержания только payer,
    # добавляем второй признак — cohort
    if retention.index.nlevels == 1:
        retention['cohort'] = 'All users'
        retention = retention.reset_index().set_index(['cohort', 'payer'])

    # в таблице графиков — два столбца и две строки, четыре ячейки
    # в первой строим кривые удержания платящих пользователей
    ax1 = plt.subplot(2, 2, 1)
    retention.query('payer == True').droplevel('payer').T.plot(
        grid=True, ax=ax1
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание платящих пользователей')

    # во второй ячейке строим кривые удержания неплатящих
    # вертикальная ось — от графика из первой ячейки
    ax2 = plt.subplot(2, 2, 2, sharey=ax1)
    retention.query('payer == False').droplevel('payer').T.plot(
        grid=True, ax=ax2
    )
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Удержание неплатящих пользователей')

    # в третьей ячейке — динамика удержания платящих
    ax3 = plt.subplot(2, 2, 3)
    # получаем названия столбцов для сводной таблицы
    columns = [
        name
        for name in retention_history.index.names
        if name not in ['dt', 'payer']
    ]
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == True').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания платящих пользователей на {}-й день'.format(
            horizon
        )
    )

    # в чётвертой ячейке — динамика удержания неплатящих
    ax4 = plt.subplot(2, 2, 4, sharey=ax3)
    # фильтруем данные и строим график
    filtered_data = retention_history.query('payer == False').pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax4)
    plt.xlabel('Дата привлечения')
    plt.title(
        'Динамика удержания неплатящих пользователей на {}-й день'.format(
            horizon
        )
    )
    
    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации конверсии

def plot_conversion(conversion, conversion_history, horizon, window=7):

    # задаём размер сетки для графиков
    plt.figure(figsize=(15, 5))

    # исключаем размеры когорт
    conversion = conversion.drop(columns=['cohort_size'])
    # в таблице динамики оставляем только нужный лайфтайм
    conversion_history = conversion_history.drop(columns=['cohort_size'])[
        [horizon - 1]
    ]

    # первый график — кривые конверсии
    ax1 = plt.subplot(1, 2, 1)
    conversion.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('Конверсия пользователей')

    # второй график — динамика конверсии
    ax2 = plt.subplot(1, 2, 2, sharey=ax1)
    columns = [
        # столбцами сводной таблицы станут все столбцы индекса, кроме даты
        name for name in conversion_history.index.names if name not in ['dt']
    ]
    filtered_data = conversion_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика конверсии пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
# функция для визуализации LTV и ROI

def plot_ltv_roi(ltv, ltv_history, roi, roi_history, horizon, window=7):

    # задаём сетку отрисовки графиков
    plt.figure(figsize=(20, 10))

    # из таблицы ltv исключаем размеры когорт
    ltv = ltv.drop(columns=['cohort_size'])
    # в таблице динамики ltv оставляем только нужный лайфтайм
    ltv_history = ltv_history.drop(columns=['cohort_size'])[[horizon - 1]]

    # стоимость привлечения запишем в отдельный фрейм
    cac_history = roi_history[['cac']]

    # из таблицы roi исключаем размеры когорт и cac
    roi = roi.drop(columns=['cohort_size', 'cac'])
    # в таблице динамики roi оставляем только нужный лайфтайм
    roi_history = roi_history.drop(columns=['cohort_size', 'cac'])[
        [horizon - 1]
    ]

    # первый график — кривые ltv
    ax1 = plt.subplot(2, 3, 1)
    ltv.T.plot(grid=True, ax=ax1)
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('LTV')

    # второй график — динамика ltv
    ax2 = plt.subplot(2, 3, 2, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in ltv_history.index.names if name not in ['dt']]
    filtered_data = ltv_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax2)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика LTV пользователей на {}-й день'.format(horizon))

    # третий график — динамика cac
    ax3 = plt.subplot(2, 3, 3, sharey=ax1)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in cac_history.index.names if name not in ['dt']]
    filtered_data = cac_history.pivot_table(
        index='dt', columns=columns, values='cac', aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax3)
    plt.xlabel('Дата привлечения')
    plt.title('Динамика стоимости привлечения пользователей')

    # четвёртый график — кривые roi
    ax4 = plt.subplot(2, 3, 4)
    roi.T.plot(grid=True, ax=ax4)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.legend()
    plt.xlabel('Лайфтайм')
    plt.title('ROI')

    # пятый график — динамика roi
    ax5 = plt.subplot(2, 3, 5, sharey=ax4)
    # столбцами сводной таблицы станут все столбцы индекса, кроме даты
    columns = [name for name in roi_history.index.names if name not in ['dt']]
    filtered_data = roi_history.pivot_table(
        index='dt', columns=columns, values=horizon - 1, aggfunc='mean'
    )
    filter_data(filtered_data, window).plot(grid=True, ax=ax5)
    plt.axhline(y=1, color='red', linestyle='--', label='Уровень окупаемости')
    plt.xlabel('Дата привлечения')
    plt.title('Динамика ROI пользователей на {}-й день'.format(horizon))

    plt.tight_layout()
    plt.show()

# %%
#Функция честно сворована и чуть-оптимизирована - https://www.statology.org/seaborn-barplot-show-values/
#Есть более простой способ, но он требует более новой версии MatPlotLib.PyPlot

def display_values(axs, space=.001):
    def _single(ax):
        for p in ax.patches:
            _x = p.get_x() + p.get_width() / 2
            _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
            value = '{:.1f}'.format(p.get_height())
            ax.text(_x, _y, value, ha="center") 

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %% [markdown]
# Необходимые для анализа и визуализации результатов **функции заданы.**
#
# Переходим к непосредственной работе с имеющимися данными:

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Составьте профили пользователей. Определите минимальную и максимальную даты привлечения пользователей.

# %%
# Получаем профили пользователей с помощью модицифированной функции:
profiles = get_profiles(visits, orders, costs)
display(profiles.head(5))
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost
# 0  2019-05-07 2019-05-01   True              1.09
# 1  2019-07-09 2019-07-01  False              1.11
# 2  2019-10-01 2019-10-01  False              0.00
# 3  2019-08-22 2019-08-01  False              0.99
# 4  2019-10-02 2019-10-01  False              0.23

# %%
#Определяем минимальную и максимальную даты привлечения:
date_search = profiles.sort_values(by='dt', ascending=False)

#Отображаем первую и последнюю строку датафрейма, отсортированному по дате привлечения пользователя
display(date_search.head(1))
display(date_search.tail(1))
# Out:
#             user_id            first_ts   channel  device         region  \
# 82357  546904409311 2019-10-27 19:16:27  FaceBoom  iPhone  United States
#
#                dt      month  payer  acquisition_cost
# 82357  2019-10-27 2019-10-01  False              1.13
#            user_id            first_ts  channel   device  region          dt  \
# 10301  68604075597 2019-05-01 04:40:39  LeapBob  Android  France  2019-05-01
#
#            month  payer  acquisition_cost
# 10301 2019-05-01  False              0.21

# %% [markdown]
# **Выводы:**
#
# - **Профили пользователей успешно сформированы** и готовы к применению для расчёта ключевых метрик исследования
# - Как и было указано в описании проекта - **минимальной датой привлечения пользователей является 1 мая 2019 года, а максимальной - 27 октября 2019 года.**

# %% [markdown]
# ### Выясните, из каких стран пользователи приходят в приложение и на какую страну приходится больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих из каждой страны.

# %%
region_data = profiles.groupby('region').agg({'user_id':'nunique', 'payer':'mean'})
region_data['payer'] = region_data['payer'] * 100
region_data = region_data.sort_values(by='payer', ascending=False)
region_data
# Out:
#                user_id  payer
# region
# United States   100002   6.90
# Germany          14981   4.11
# UK               17575   3.98
# France           17450   3.80

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
first = sns.barplot(data=region_data, 
            x=region_data.index, 
            y='user_id',
            palette="Blues_r",
            ax=ax[0])
display_values(first)
first.set(xlabel='Страна', ylabel='Число пользователей')

second = sns.barplot(data=region_data, 
        x=region_data.index, 
        y='payer',
        palette="Blues_r",
        ax=ax[1])
display_values(second)
second.set(xlabel='Страна', ylabel='Доля плательщиков')

ax[0].set_title("Число пользователей из различных регионов", weight='bold').set_fontsize(12)
ax[1].set_title("Доля платящих пользователей в каждом регионе", weight='bold').set_fontsize(12)
plt.show();

# %% [markdown]
# **Выводы:**
# - **Больше всего уникальных пользователей из Соединённых Штатов** (100.002), число пользователей из других стран значительно меньше (от 14.981 из Германии до 17.575 в Великобритании)
# - **Наибольшая доля платящих пользователей также в США** - 6,9%. В других странах доля плательщиков ниже и составляет лишь 4% или чуть меньше.
# - **Таким образом, наиболее "интересная" аудитория - жители США** (их больше всего и среди них больше плательщиков), однако и в других странах присутствует потенциал.

# %% [markdown]
# ### Узнайте, какими устройствами пользуются клиенты и какие устройства предпочитают платящие пользователи. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого устройства.

# %%
device_data_general = profiles.groupby('device').agg({'user_id':'nunique', 'payer':'mean'})
device_data_general = device_data_general.sort_values(by='payer', ascending=False)
device_data_general
# Out:
#          user_id  payer
# device
# Mac        30042   0.06
# iPhone     54479   0.06
# Android    35032   0.06
# PC         30455   0.05

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
first = sns.barplot(data=device_data_general, 
            x=device_data_general.index, 
            y='user_id',
            palette="Blues_r",
            ax=ax[0])
display_values(first)
first.set(xlabel='Устройство', ylabel='Число пользователей')

second = sns.barplot(data=device_data_general, 
        x=device_data_general.index, 
        y='payer',
        palette="Blues_r",
        ax=ax[1])
second.set(xlabel='Устройство', ylabel="Доля плательщиков")

ax[0].set_title("Число пользователей на каждом устройстве", weight='bold').set_fontsize(12)
ax[1].set_title("Доля платящих пользователей по устройствам", weight='bold').set_fontsize(12)
plt.show();

# %%
#Сколько всего мобильных пользователей, а сколько - десктопных?
device_map = {'Mac': 'desktop',
             'PC': 'desktop',
              'iPhone': 'mobile',
             'Android': 'mobile'}

visits['device_type'] = visits['device'].map(device_map);
visits.head(1)
# Out:
#         user_id         region  device  channel       session_start  \
# 0  981449118918  United States  iPhone  organic 2019-05-01 02:36:01
#
#           session_end device_type
# 0 2019-05-01 02:45:01      mobile

# %%
#Аналогичная процедура и в профилях - для дальнейшего анализа
#Сколько всего мобильных пользователей, а сколько - десктопных?
profiles['device_type'] = profiles['device'].map(device_map);
profiles.head(5)
# Out:
#     user_id            first_ts     channel  device         region  \
# 0    599326 2019-05-07 20:58:57    FaceBoom     Mac  United States
# 1   4919697 2019-07-09 12:46:07    FaceBoom  iPhone  United States
# 2   6085896 2019-10-01 09:58:33     organic  iPhone         France
# 3  22593348 2019-08-22 21:35:48  AdNonSense      PC        Germany
# 4  31989216 2019-10-02 00:07:44     YRabbit  iPhone  United States
#
#            dt      month  payer  acquisition_cost device_type
# 0  2019-05-07 2019-05-01   True              1.09     desktop
# 1  2019-07-09 2019-07-01  False              1.11      mobile
# 2  2019-10-01 2019-10-01  False              0.00      mobile
# 3  2019-08-22 2019-08-01  False              0.99     desktop
# 4  2019-10-02 2019-10-01  False              0.23      mobile

# %%
device_type_data = profiles.groupby('device_type').agg({'user_id':'nunique', 'payer':'mean'})
device_type_data = device_type_data.sort_values(by='payer', ascending=False)

device_type_data
# Out:
#              user_id  payer
# device_type
# mobile         89511   0.06
# desktop        60497   0.06

# %%
plt.figsize=(12,6)
first = sns.barplot(data=device_type_data, 
            x=device_type_data.index, 
            y='user_id',
            palette="Blues_r")
display_values(first)
first.set(xlabel='Тип устройства', ylabel='Число пользователей')

plt.title("Число пользователей по типам устройств", weight='bold').set_fontsize(14)
plt.show()

# %% [markdown]
# **Выводы:**
# - **Самое популярное устройство - айфон**. Меньше пользуются андроидами, а меньше всего - ПК и МАКами.
# - При этом **заходов с мобильных устройств в приложение примерно на 50% больше,** чем с персональных компьютеров.
# - **Доли платящих примерно одинаковы на разных устройствах**.

# %% [markdown]
# ### Изучите рекламные источники привлечения и определите каналы, из которых пришло больше всего платящих пользователей. Постройте таблицу, отражающую количество пользователей и долю платящих для каждого канала привлечения.

# %%
channel_data = profiles.groupby('channel').agg({'user_id':'nunique', 'payer':'mean'})
channel_data = channel_data.sort_values(by='payer', ascending=False)
channel_data['payers_brought'] = channel_data['user_id'] * channel_data['payer']

channel_data.columns = [['Всего привлечено пользователей', "Доля плательщиков", "Всего привлечено плательщиков"]]
channel_data
# Out:
#                    Всего привлечено пользователей Доля плательщиков  \
# channel
# FaceBoom                                    29144              0.12
# AdNonSense                                   3880              0.11
# lambdaMediaAds                               2149              0.10
# TipTop                                      19561              0.10
# RocketSuperAds                               4448              0.08
# WahooNetBanner                               8553              0.05
# YRabbit                                      4312              0.04
# MediaTornado                                 4364              0.04
# LeapBob                                      8553              0.03
# OppleCreativeMedia                           8605              0.03
# organic                                     56439              0.02
#
#                    Всего привлечено плательщиков
# channel
# FaceBoom                                 3557.00
# ...

# %% [markdown]
# **Вывод:**
#
# - **Больше всего пользователей пришло не по результатам привлечения, а органично** - 56.439. При этом доля плательщиков среди этих пользователей крайне мала - около 2%.
# - Из прочих источников **однозначным лидеров является FaceBoom** - 29.144 новых пользователей, из которых 12% - плательщики (3557).
# - **На втором месте закрепился TipTop** - 19.561 пользователей, 10% из которых - плательщики (1878).

# %% [markdown]
# ### Маркетинг
#
# - Посчитайте общую сумму расходов на маркетинг.
# - Выясните, как траты распределены по рекламным источникам, то есть сколько денег потратили на каждый источник.
# - Постройте визуализацию динамики изменения расходов во времени (по неделям и месяцам) по каждому источнику. Постарайтесь отразить это на одном графике.
# - Узнайте, сколько в среднем стоило привлечение одного пользователя (CAC) из каждого источника. Используйте профили пользователей.
#
# Напишите промежуточные выводы.

# %% [markdown]
# **Для начала - давайте оценим затраты на маркетинг. Сколько всего было потрачено средств?**

# %%
#Рассмотрим общую сумму затрат на маркетинг
total_costs = costs['costs'].sum()
print(f'Общая сумма затрат на маркетинг за исследуемый период составляет {total_costs:0.1f}')
# Out:
# Общая сумма затрат на маркетинг за исследуемый период составляет 105497.3

# %%
#Оценим затраты на маркетинг по отдельным источникам
channel_costs = costs.groupby('channel').agg({'costs':'sum'})
channel_costs = channel_costs.sort_values(by='costs', ascending=False)
channel_costs.columns = ['Затраты на маркетинг по каналу']
channel_costs
# Out:
#                     Затраты на маркетинг по каналу
# channel
# TipTop                                    54751.30
# FaceBoom                                  32445.60
# WahooNetBanner                             5151.00
# AdNonSense                                 3911.25
# OppleCreativeMedia                         2151.25
# RocketSuperAds                             1833.00
# LeapBob                                    1797.60
# lambdaMediaAds                             1557.60
# MediaTornado                                954.48
# YRabbit                                     944.22

# %% [markdown]
# Видим, что **затраты на маркетинг в значительной степени сосредоточены вокруг двух основных каналов - TipTop и FaceBoom.** Теперь давайте посмотрим изменение расходов по источникам во времени.

# %%
#Добавим строчку c номером недели для анализа
costs['dt_week'] = pd.to_datetime(costs['dt']).dt.isocalendar().week
costs['dt_month'] = pd.to_datetime(costs['dt']).dt.month

#Создадим сводную таблицу для хитмепа
channel_costs_over_time = costs.pivot_table(index=['dt_month', 'dt_week'], columns='channel', values='costs', aggfunc='sum')
channel_costs_over_time = channel_costs_over_time.T
channel_costs_over_time['total'] = channel_costs_over_time.sum(axis=1)
channel_costs_over_time = channel_costs_over_time.sort_values(by='total', ascending=False).drop(columns='total').T

#Отрисуем хитмеп на основании таблицы
plt.figure(figsize=(22,10))
heatmap = sns.heatmap(channel_costs_over_time.T,
           annot=True,
           fmt='g',
           annot_kws={'size':10})
heatmap.set(xlabel='Месяц-Неделя', ylabel='Канал привлечения')

plt.title("Изменение инвестиций в маркетинг по источникам в разрезе по времени", weight='bold').set_fontsize(16)
plt.show();

# %% [markdown]
# **Наложение на один график даёт какой-то результат - однако не слишком наглядный.** Уже можно сделать выводы о том, что больше всего денег было потрачено на TipTop и FaceBoom, при этом **пик затрат пришёлся на предпоследнюю неделю сентября**, а на следующей неделе напротив был определённый "провал" - траты на многие источники снизились на много порядков (в некоторых случаях - более чем в 10 раз!).
#
# Взглянем на этот показатель отдельно:

# %%
channel_costs_over_time.query('dt_week in (39,40)')
# Out:
# channel           TipTop  FaceBoom  WahooNetBanner  AdNonSense  \
# dt_month dt_week
# 9        39      3979.50   1837.00          303.00      192.15
#          40       553.00    260.70           45.00       27.30
# 10       40      3150.00   1500.40          264.00      128.10
#
# channel           OppleCreativeMedia  RocketSuperAds  LeapBob  lambdaMediaAds  \
# dt_month dt_week
# 9        39                   132.25           63.70   101.22           80.00
#          40                    22.75            9.43    18.69            7.20
# 10       40                   100.25           56.88    82.32           52.00
#
# channel           MediaTornado  YRabbit
# dt_month dt_week
# 9        39              48.24    47.52
#          40               5.28     5.04
# 10       40              36.72    40.32

# %% [markdown]
# Это несколько объясняет ситуацию - **неделя разбита между двумя месяцами,** отчего затраты на её "сентябрьскую" часть оказались малы.

# %% [markdown]
# **Давайте попробуем посмотреть на маркетинговые траты в разбивке по времени...**
#
# Для этого используем `lineplot`:

# %%
#Создадим общую сводную таблицу
channel_costs_over_time_general = costs.pivot_table(index='dt', columns='channel', values='costs', aggfunc='sum')
channel_costs_over_time_general = channel_costs_over_time_general.T
channel_costs_over_time_general['total'] = channel_costs_over_time_general.sum(axis=1)
channel_costs_over_time_general = channel_costs_over_time_general.sort_values(by='total', ascending=False).drop(columns='total').T

#Отрисуем график

plt.figure(figsize=(16,8))
sns.lineplot(data=channel_costs_over_time_general,
            markers=True)

plt.xlabel("Дата")
plt.title("Изменение инвестиций в маркетинг по источникам в разрезе по времени", weight='bold').set_fontsize(16)
plt.show();

# %% [markdown]
# **Общая картина примерно понятна - заметны всё те же два очевидных лидера**, в то время как остальные каналы остались позади. Давайте немного "сгладим" график и посмотрим на результаты в разрезе недель/месяцев, чтобы получше рассмотреть общую динамику.

# %%
#Создадим сводные таблицы для лайнплотов
channel_costs_over_time_weeks = costs.pivot_table(index='dt_week', columns='channel', values='costs', aggfunc='sum')
channel_costs_over_time_weeks = channel_costs_over_time_weeks.T
channel_costs_over_time_weeks['total'] = channel_costs_over_time_weeks.sum(axis=1)
channel_costs_over_time_weeks = channel_costs_over_time_weeks.sort_values(by='total', ascending=False).drop(columns='total').T

channel_costs_over_time_months = costs.pivot_table(index='dt_month', columns='channel', values='costs', aggfunc='sum')
channel_costs_over_time_months = channel_costs_over_time_months.T
channel_costs_over_time_months['total'] = channel_costs_over_time_months.sum(axis=1)
channel_costs_over_time_months = channel_costs_over_time_months.sort_values(by='total', ascending=False).drop(columns='total').T

#График с изменением по месяцам
sns.set_theme(style='whitegrid')

fig, ax = plt.subplots(1, 2, figsize=(16, 8));
fig.suptitle("Изменение инвестиций в маркетинг по источникам в разрезе по времени", weight='bold').set_fontsize(16);

#Первый график - по неделям
first = sns.lineplot(data=channel_costs_over_time_weeks,
            markers=True,
            ax=ax[0])
first.set(xlabel='Недели')

#Второй график - по месяцам
second = sns.lineplot(data=channel_costs_over_time_months,
            markers=True,
            ax=ax[1])
second.set(xlabel='Месяца')

ax[0].set_title("$В$ $разбивке$ $по$ $неделям$...").set_fontsize(13);
ax[1].set_title("$В$ $разбивке$ $по$ $месяцам$...").set_fontsize(13);
plt.show();

# %% [markdown]
# **Общая картина примерно понятна - расходы на два крупнейших источника продолжали расти** на протяжении всего исследуемого периода, в то время как затраты на прочие источники оставались на низком уровне.
#
# При этом стоит обратить внимание на **расходы на TipTop - они крайне высоки и продолжают расти, хотя FaceBoom принёс больше пользователей.**
#
# Для этого нужно посмотреть на затраты на привлечение одного пользователя по источникам:

# %%
#Построим общую таблицу CAC.
cac_table_general = profiles.groupby('channel').agg({'acquisition_cost':'mean'})
cac_table_general = cac_table_general.sort_values(by='acquisition_cost', ascending=False)

cac_table_general.columns = ['Стоимость привлечения одного пользователя']

cac_table_general
# Out:
#                     Стоимость привлечения одного пользователя
# channel
# TipTop                                                   2.80
# FaceBoom                                                 1.11
# AdNonSense                                               1.01
# lambdaMediaAds                                           0.72
# WahooNetBanner                                           0.60
# RocketSuperAds                                           0.41
# OppleCreativeMedia                                       0.25
# YRabbit                                                  0.22
# MediaTornado                                             0.22
# LeapBob                                                  0.21
# organic                                                  0.00

# %% [markdown]
# Здесь мы **уже видим проблему - больше всего средств выделяется двум каналам, привлечение одного пользователя в которых в среднем за исследуемый период обходится дороже всего.** При этом **средний пользователь из TipTop в 2 раза дороже, чем из второго по цене канала.**
#
# Само по себе **это не обязательно является проблемой** - ведь **необходимо оценить также и LTV каждого пользователя** и примерные темпы окупаемости рекламы. Этим займёмся чуть дальше, и будем держать в виду полученные здесь инсайты.

# %% [markdown]
# **Выводы:**
# - **Общая стоимость расходов на маркетинг за исследуемый период составила 105 497.**
# - **Значительная часть этого бюджета сосредоточена в двух источниках - это TipTop и FaceBoom.** Из анализа числа привлечённых пользователей знаем, что это те источники, которые привлекли много клиентов, однако и **стоимость привлечения каждого пользователя в этих источниках значительно выше, чем в других** (особенно дорогие пользователи в TipTop - более чем в 2 раза дороже, чем у ближайшего по цене конкурента!)
# - Анализ динамики изменения расходов показывает, что **расходы на два крупнейших источники изначально были несколько выше, чем на другие**, а также **продолжали расти на протяжении большей части исследуемого периода.** При этом **затраты на TipTop росли особенно сильно,** и на данный момент превышают затраты на FaceBoom (и на все остальные источники), при этом цена привлечения одного пользователя крайне высока, по сравнению с прочими источниками.

# %% [markdown]
# ### Оцените окупаемость рекламы
#
# Используя графики LTV, ROI и CAC, проанализируйте окупаемость рекламы. Считайте, что на календаре 1 ноября 2019 года, а в бизнес-плане заложено, что пользователи должны окупаться не позднее чем через две недели после привлечения. Необходимость включения в анализ органических пользователей определите самостоятельно.
#
# - Проанализируйте окупаемость рекламы c помощью графиков LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проверьте конверсию пользователей и динамику её изменения. То же самое сделайте с удержанием пользователей. Постройте и изучите графики конверсии и удержания.
# - Проанализируйте окупаемость рекламы с разбивкой по устройствам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по странам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Проанализируйте окупаемость рекламы с разбивкой по рекламным каналам. Постройте графики LTV и ROI, а также графики динамики LTV, CAC и ROI.
# - Ответьте на такие вопросы:
#     - Окупается ли реклама, направленная на привлечение пользователей в целом?
#     - Какие устройства, страны и рекламные каналы могут оказывать негативное влияние на окупаемость рекламы?
#     - Чем могут быть вызваны проблемы окупаемости?
#
# Напишите вывод, опишите возможные причины обнаруженных проблем и промежуточные рекомендации для рекламного отдела.

# %%
#Для начала зададим вводные показатели:

observation_date = dt.datetime(2019, 11, 1).date()

horizon_days = 14 #Заданный горизонт анализа - две недели

# %% [markdown]
# Будем двигаться по порядку поставленных задач - для простоты проверки (и, теоретически - отчётности).
#
# Для начала **оценим окупаемость рекламы:**

# %%
# Посчитаем показатели в целом
ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days) #Знаю, что можно не дублировать

#Визуализируем полученные данные
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %% [markdown]
# Какие можно сделать **выводы из имеющихся графиков?**
#
# - **LTV распределён ожидаемо - со временем он растёт, при этом рост постепенно замедляется.**
# - За время исследования **LTV пользователей на 14 день менялось, однако это были колебания - в целом, метрика остаётся примерно на одном уровне.**
# - А вот **стоимость привлечения новых пользователей за это же время выросла многократно** - после значительного скачка в июне темпы роста несколько замедлились, однако всё равно остатся значительными и не коррелируют с динамикой LTV пользователей - **цена на привлечение одного пользователя выросла многократно, а вот доход с него - практически не изменился.**
# - Последние два графика подтверждают эти выводы - мы видим, что за весь период исследования **пользователи за 2 недели лишь подходят к окупаемости, не начиная приносить прибыли.** В то же время ситуация является таковой именно за счёт роста стоимости - **резкое падение темпов окупаемости вложений, которое видно на последнем графике по времени совпадает с ростом стоимости привлечения пользователей.**

# %% [markdown]
# Пойдём дальше - оценим **конверсию и удержание пользователей**

# %%
#Начнём с конверсии

conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles,
                                                                       orders,
                                                                       observation_date=observation_date,
                                                                       horizon_days=horizon_days)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
#А теперь давайте посмотрим на удержание пользователей

retention_raw, retention_grouped, retention_history = get_retention(profiles,
                                                                   visits,
                                                                   observation_date=observation_date,
                                                                   horizon_days=horizon_days)

plot_retention(retention_grouped, retention_history, horizon_days)

# %% [markdown]
# Всё выглядит относительно стандартно. Отдельно стоит отметить **значительный рост конверсии с мая по июль** (который отчасти коррелируют с ростом затрат на привлечение пользователей), однако **отсутствие подобного роста в метрике удержания** (пусть и более сдержанного), который после определённого положительного колебания в этот момент вернулся на прежние позиции.
#
# При этом видим, что **показатели конверии и удержания могут быть улучшены, однако в целом не являются очень низкими.** Это значит, что проблема находится несколько глубже - нужно посмотреть на эти показатели в разбивке...

# %%
#Для начала давайте посмотрим на окупаемость рекламы с разбивкой по устройствам...
dimensions = ['device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days,
                                                                     dimensions=dimensions) #Знаю, что можно не дублировать

#Визуализируем полученные данные
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %%
#Посмотрим на показатели конверсии и удержания по интересующим нас устройствам:
dimensions = ['device']

retention_raw, retention_grouped, retention_history = get_retention(profiles,
                                                                   visits,
                                                                   observation_date=observation_date,
                                                                   horizon_days=horizon_days,
                                                                   dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days)

conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles,
                                                                       orders,
                                                                       observation_date=observation_date,
                                                                       horizon_days=horizon_days,
                                                                       dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Графики демонстрируют нам **несколько интересных моментов:**
# - Рост стоимости привлечения пользователей значителен на всех устройствах - однако, мы видим, что за исследуемый период **особенно сильно выросла стоимость привлечения пользователей Mac и iPhone**, в то время как за две недели, которые мы отвели в качестве горизонта анализа **эти пользователи не выходят на окупаемость.**
# - При этом **динамика LTV и ROI на 14 день в целом ожидаема - значительные колебания, при этом Mac и iPhone уходят в значительный минус.**

# %%
#Давайте посмотрим на эти показатели в разбивке по странам

dimensions = ['region']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days,
                                                                     dimensions=dimensions) #Знаю, что можно не дублировать

#Визуализируем полученные данные
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %%
#Посмотрим на показатели конверсии и удержания по интересующим нас странам:
dimensions = ['region']

retention_raw, retention_grouped, retention_history = get_retention(profiles,
                                                                   visits,
                                                                   observation_date=observation_date,
                                                                   horizon_days=horizon_days,
                                                                   dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days)

conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles,
                                                                       orders,
                                                                       observation_date=observation_date,
                                                                       horizon_days=horizon_days,
                                                                       dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %% [markdown]
# Разбивка по регионам дала **важные выводы:**
# - **Значения метрик пользователей трёх стран (Франция, Германия и Великобритания) в целом находились на одном уровне**, эти пользователи **выходили на окупаемость по истечению периода анализа.**
# - А вот **пользователи из Соединённых Штатов напротив, не выходят на окупаемость и являются главной причиной роста стоимости привлечённых пользователей** - стоимость привлечения пользователей из других стран практически не изменилась за исследуемый период, в то время как стоимость пользователей из США значительно выросла.
# - Примечательно, что **рост расходов на маркетинг по отдельным каналам привёл к значительному росту конверсии пользователей из США, но вот удержание этой группы остаётся крайне низким.**

# %%
#Напоследок, давайте проанализируем ситуацию в разбивке по каналам...

dimensions = ['channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days,
                                                                     dimensions=dimensions) #Знаю, что можно не дублировать

#Визуализируем полученные данные
plot_ltv_roi(ltv_grouped, ltv_history, roi_grouped, roi_history, horizon_days)

# %%
#Посмотрим, какие каналы не окупаются к указанному сроку:

roi_grouped[13].sort_values(ascending=True)
# Out:
# channel
# TipTop               0.54
# FaceBoom             0.74
# AdNonSense           0.83
# WahooNetBanner       1.53
# OppleCreativeMedia   1.64
# RocketSuperAds       2.24
# LeapBob              2.25
# lambdaMediaAds       2.43
# MediaTornado         2.44
# YRabbit              2.58
# Name: 13.0, dtype: float64

# %%
#Посмотрим показатели по этим каналам в отдельности

money_sink = ['TipTop', 'FaceBoom', 'AdNonSense']

ltv_grouped_sink = ltv_grouped.query('channel in @money_sink')
ltv_history_sink = ltv_history.query('channel in @money_sink')
roi_grouped_sink = roi_grouped.query('channel in @money_sink')
roi_history_sink = roi_history.query('channel in @money_sink')

#Визуализируем полученные данные
plot_ltv_roi(ltv_grouped_sink, ltv_history_sink, roi_grouped_sink, roi_history_sink, horizon_days)

# %%
#Посмотрим на показатели конверсии и удержания:
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(profiles.query('channel in @money_sink'),
                                                                   visits,
                                                                   observation_date=observation_date,
                                                                   horizon_days=horizon_days,
                                                                   dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days)

conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles.query('channel in @money_sink'),
                                                                       orders,
                                                                       observation_date=observation_date,
                                                                       horizon_days=horizon_days,
                                                                       dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
#А теперь давайте сравним с другими каналами:

#Посмотрим на показатели конверсии и удержания:
dimensions = ['channel']

retention_raw, retention_grouped, retention_history = get_retention(profiles,
                                                                   visits,
                                                                   observation_date=observation_date,
                                                                   horizon_days=horizon_days,
                                                                   dimensions=dimensions)

plot_retention(retention_grouped, retention_history, horizon_days)

conversion_raw, conversion_grouped, conversion_history = get_conversion(profiles,
                                                                       orders,
                                                                       observation_date=observation_date,
                                                                       horizon_days=horizon_days,
                                                                       dimensions=dimensions)

plot_conversion(conversion_grouped, conversion_history, horizon_days)

# %%
costs
# Out:
#               dt         channel  costs  dt_week  dt_month
# 0     2019-05-01        FaceBoom 113.30       18         5
# 1     2019-05-02        FaceBoom  78.10       18         5
# 2     2019-05-03        FaceBoom  85.80       18         5
# 3     2019-05-04        FaceBoom 136.40       18         5
# 4     2019-05-05        FaceBoom 122.10       18         5
# ...          ...             ...    ...      ...       ...
# 1795  2019-10-23  lambdaMediaAds   4.00       43        10
# 1796  2019-10-24  lambdaMediaAds   6.40       43        10
# 1797  2019-10-25  lambdaMediaAds   8.80       43        10
# 1798  2019-10-26  lambdaMediaAds   8.80       43        10
# 1799  2019-10-27  lambdaMediaAds  12.00       43        10
#
# [1800 rows x 5 columns]

# %%
#Давайте отдельно рассмотрим - когда начался рост цен на привлечение одного пользователя в TipTop?

costs_tiptop = costs.query('channel == "TipTop"')
costs_tiptop = costs_tiptop.groupby(['dt_month', 'dt_week']).agg({'costs': 'sum'})
costs_tiptop
# Out:
#                    costs
# dt_month dt_week
# 5        18       347.00
#          19       470.00
#          20       454.00
#          21       801.80
#          22       908.20
# 6        22       513.00
#          23      1223.60
#          24      1121.00
#          25      1474.40
#          26      2343.60
# 7        27      2340.00
#          28      1820.00
#          29      1552.20
#          30      1713.40
#          31       984.60
# 8        31      1509.00
#          32      2448.00
#          33      2538.00
#          34      2514.00
#          35      2193.00
# 9        35       390.00
#          36      2563.00
#          37      2506.00
#          38      3241.00
#          39      3979.50
#          40       553.00
# 10       40      3150.00
#          41      3097.50
#          42      2737.00
#          43      3265.50

# %% [markdown]
# На основании анализа каналов мы можем разделить их на **несколько групп:**
#
# - **Три наиболее проблемных**
#     - **AdNonSense** (ROI к концу второй недели - 0.83), который на протяжении всего периода исследованя был скорее убыточен.
#         - **Причина убыточности канала: крайне низкое удержание платящих пользователей** - AdNonSense и FaceBoom демонстрируют самый худший показатель удержания пользователей за исследуемый период, причём этот показатель практически не менялся.
#     - **FaceBoom** - ситуация схожа и чуть более стабильна (у AdNonSense имеются "вспышки" прибыльности - у ряд когорт окупаемость присутствовала, в то время как FaceBoom стабильно несколько убыточен).
#         - **Причина убыточности канала: аналогично AdNonSense - крайне низкое удержание платящих пользователей** (при этом канал имеет лучшую конверсию из всех представленных).
#     - **TipTop** - на начало исследуемого периода был прибылен, однако значительный рост инвестиций в маркетинг по каналу привёл лишь к росту стоимости на рекрут одного пользователя, что в итоге сделало канал в целом убыточным.
#         - **Причина убыточности канала: слишком высокая стоимость привлечения одного пользователя** (на начало исследуемого периода этот показатель был в пределах нормы и канал демонстрировал хороший показатель ROI, однако уже **с июня начался резкий рост затрат на рекламу в этом канале**, который не привёл к такому же резкому притоку аудитории, а лишь повысил стоимость одного пользователя, в результате чего канал перестал быть прибыльным.
#     - **Последние два канала работают преимущественно с американской аудиторией.** С этой же аудиторией работают и другие каналы - более прибыльные.
#
# - **Умеренно-прибыльные** (WahooNetBanner и OppleCreativeMedia) - ROI к концу второй недели 1.53 и 1.64 соответственно. В этих каналах особенно выражены трудности с iPhone и Mac)
#
# - **Прибыльные** - остальные каналы, ROI от 2.24 и выше.

# %%
#Давайте попробуем два вывода - посмотрим, как обстоит ситуация в разбивке по каналам И устройствам:

dimensions = ['channel', 'device']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days,
                                                                     dimensions=dimensions) #Знаю, что можно не дублировать

display(roi_grouped[13])
# Out:
# channel             device
# AdNonSense          Android   0.73
#                     Mac       0.68
#                     PC        0.94
#                     iPhone    0.83
# FaceBoom            Android   0.81
#                     Mac       0.76
#                     PC        0.71
#                     iPhone    0.70
# LeapBob             Android   2.33
#                     Mac       2.73
#                     PC        2.29
#                     iPhone    1.81
# MediaTornado        Android   2.00
#                     Mac       2.54
#                     PC        2.07
#                     iPhone    2.66
# OppleCreativeMedia  Android   1.23
#                     Mac       2.02
#                     PC        1.74
#                     iPhone    1.82
# RocketSuperAds      Android   1.43
#                     Mac       2.61
#                     PC        1.89
#                     iPhone    2.49
# TipTop              Android   0.63
#                     Mac       0.49
# ...

# %%
#Аналогично по каналам и регионам:

dimensions = ['region', 'channel']

ltv_raw, ltv_grouped, ltv_history, roi_grouped, roi_history = get_ltv(profiles,
                                                                     orders,
                                                                     observation_date=observation_date,
                                                                     horizon_days=horizon_days,
                                                                     dimensions=dimensions) #Знаю, что можно не дублировать

display(roi_grouped[13])
# Out:
# region         channel
# France         AdNonSense           0.75
#                LeapBob              2.14
#                OppleCreativeMedia   1.48
#                WahooNetBanner       1.48
#                lambdaMediaAds       2.35
# Germany        AdNonSense           0.90
#                LeapBob              2.06
#                OppleCreativeMedia   1.50
#                WahooNetBanner       1.64
#                lambdaMediaAds       2.29
# UK             AdNonSense           0.85
#                LeapBob              2.52
#                OppleCreativeMedia   1.91
#                WahooNetBanner       1.47
#                lambdaMediaAds       2.62
# United States  FaceBoom             0.74
#                MediaTornado         2.44
#                RocketSuperAds       2.24
#                TipTop               0.54
#                YRabbit              2.58
# Name: 13.0, dtype: float64

# %% [markdown]
# Можно сделать следующие **выводы по странам и источникам:**
# - **В европейском регионе** (Франция, Германия и Великобритания) все каналы работают хорошо или умеренно-хорошо, за исключением `AdNonSense`, проблемы с которым мы рассматривали ранее.
# - **В США три канала работают очень хорошо** и показывают высокие показатели ROI за тестируемый период - за 2 недели `MediaTornado`, `RocketSuperAds` и `YRabbit` вышли на показатели в 244%, 224% и 258% соответственно! В то же время **два проблемных канала также работают на территории США **- это `FaceBoom` и `TipTop`, проблемы которых были обозначенны ранее.

# %% [markdown]
# ## Общие выводы
#
# - Выделите причины неэффективности привлечения пользователей.
# - Сформулируйте рекомендации для отдела маркетинга.

# %% [markdown]
# **Выводы:**
#
# - **Общая характеристика исследуемых групп:**
#     - **Больше всего уникальных пользователей из Соединённых Штатов** (100.002), число пользователей из других стран значительно меньше (от 14.981 из Германии до 17.575 в Великобритании)
#     - Самая интересная аудитория (на которой рекомендуется сосредоточить внимание) - жители США. Помимо того, что их больше всего, среди них и больше всего плательщиков (6,9% против ~4% среди пользователей)
#     - **Самое популярное устройство - айфон**. Меньше пользуются андроидами, а меньше всего - ПК и МАКами. При этом **заходов с мобильных устройств в приложение примерно на 50% больше,** чем с персональных компьютеров. а **доли платящих примерно одинаковы на разных устройствах**.
#     - **Больше всего пользователей пришло не по результатам привлечения, а органично** - 56.439. При этом доля плательщиков среди этих пользователей крайне мала - около 2%.
#     - Из прочих источников **однозначным лидеров является FaceBoom** - 29.144 новых пользователей, из которых 12% - плательщики (3557), **на втором месте закрепился TipTop** - 19.561 пользователей, 10% из которых - плательщики (1878).

# %% [markdown]
# - **Маркетинг:**
#     - **Общая стоимость расходов на маркетинг за исследуемый период составила 105 497.**
#     - **Значительная часть этого бюджета сосредоточена в двух источниках - это TipTop и FaceBoom.** Из анализа числа привлечённых пользователей знаем, что это те источники, которые привлекли много клиентов, однако и **стоимость привлечения каждого пользователя в этих источниках значительно выше, чем в других** (особенно дорогие пользователи в TipTop - более чем в 2 раза дороже, чем у ближайшего по цене конкурента!)
#     - Анализ динамики изменения расходов показывает, что **расходы на два крупнейших источники изначально были несколько выше, чем на другие**, а также **продолжали расти на протяжении большей части исследуемого периода.** При этом **затраты на TipTop росли особенно сильно,** и на данный момент превышают затраты на FaceBoom (и на все остальные источники), при этом цена привлечения одного пользователя крайне высока, по сравнению с прочими источниками.
#     - Средний доход с пользователя за исследуемый период практически не менялся, в то время как **стоимость привлечения новых пользователей за это же время выросла многократно** - после значительного скачка в июне темпы роста несколько замедлились, однако всё равно остатся значительными и не коррелируют с динамикой LTV пользователей.
#     - **За 2 недели пользователи лишь подходят к окупаемости, не начиная приносить прибыли.** В то же время ситуация является таковой именно за счёт роста стоимости - **резкое падение темпов окупаемости вложений, по времени совпадает с ростом стоимости привлечения пользователей.**

# %% [markdown]
# - **Проблемные точки:**
#     - **Устройства:**
#         - Рост стоимости привлечения пользователей значителен на всех устройствах - однако, мы видим, что за исследуемый период **особенно сильно выросла стоимость привлечения пользователей Mac и iPhone**, в то время как за две недели, которые мы отвели в качестве горизонта анализа **эти пользователи не выходят на окупаемость.**
#         - При этом **динамика LTV и ROI на 14 день в целом ожидаема - значительные колебания, при этом Mac и iPhone уходят в значительный минус.**
#         - Рекомендуется **обратить отдельное внимание на проблемы с инфраструктурой Apple** - в чём проблема, на каком этапе возникают трудности. Особенно актуально ввиду большого числа пользователей iPhone, а также ввиду того, что конверсия и удержание несколько выше у пользователей iPhone и Mac.
#
#     - **Каналы:**
#
#         - **Три наиболее проблемных**
#             - **AdNonSense** (ROI к концу второй недели - 0.83), который на протяжении всего периода исследованя был скорее убыточен.
#                 - **Причина убыточности канала: крайне низкое удержание платящих пользователей** - AdNonSense и FaceBoom демонстрируют самый худший показатель удержания пользователей за исследуемый период, причём этот показатель практически не менялся.
#             - **FaceBoom** - ситуация схожа и чуть более стабильна (у AdNonSense имеются "вспышки" прибыльности - у ряд когорт окупаемость присутствовала, в то время как FaceBoom стабильно убыточен).
#                 - **Причина убыточности канала: аналогично AdNonSense - крайне низкое удержание платящих пользователей** (при этом канал имеет лучшую конверсию из всех представленных).
#             - **TipTop** - на начало исследуемого периода был прибылен, однако значительный рост инвестиций в маркетинг по каналу привёл лишь к росту стоимости на рекрут одного пользователя, что в итоге сделало канал в целом убыточным.
#                 - **Причина убыточности канала: слишком высокая стоимость привлечения одного пользователя** (на начало исследуемого периода этот показатель был в пределах нормы и канал демонстрировал хороший показатель ROI, однако уже **с июня начался резкий рост затрат на рекламу в этом канале**, который не привёл к такому же резкому притоку аудитории, а лишь повысил стоимость одного пользователя, в результате чего канал перестал быть прибыльным.
#         - **Умеренно-прибыльные** (WahooNetBanner и OppleCreativeMedia) - ROI к концу второй недели 1.53 и 1.64 соответственно. В этих каналах особенно выражены трудности с iPhone и Mac)
#
#         - **Прибыльные** - остальные каналы, ROI от 2.24 и выше.
#
#         - Рекомендуется **обратить внимание на наиболее проблемные каналы** - и либо перестроить финансовую модель взаимодействия с ними, либо работать по другим каналам. В отношении этих каналов заметно, что **конверсия пользователей относительно неплоха, однако удержание пользователей по этим каналам находится на крайне низком уровне** по сравнению с другими - на это рекомендуется обратить отдельное внимание.
#     - **Регионы:**
#         - **Значения метрик пользователей трёх стран (Франция, Германия и Великобритания) в целом находились на одном уровне**, эти пользователи **выходили на окупаемость по истечению периода анализа** (исключение - пользователи, привлечённые каналом AdNonSense)
#         - А вот **пользователи из Соединённых Штатов напротив, не выходят на окупаемость и являются главной причиной роста стоимости привлечённых пользователей** - стоимость привлечения пользователей из других стран практически не изменилась за исследуемый период, в то время как стоимость пользователей из США значительно выросла.
#             - **Причина этого** - проблемы конкретных каналов. В США три канала работают очень хорошо и показывают высокие показатели ROI за тестируемый период - за 2 недели `MediaTornado`, `RocketSuperAds` и `YRabbit` вышли на показатели в 244%, 224% и 258% соответственно! В то же время два проблемных канала также работают на территории США - это `FaceBoom` и `TipTop`
#             - Несмотря на рост конверсии в результате роста трат на маркетинг по двум ключевым каналам, работающим по аудитории США, **удержание американских пользователей остаётся ключевой проблемной точкой этой группы** (значительно ниже, чем в других странах) - рекомендуется обратить отдельное внимание этому аспекту.
